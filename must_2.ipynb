# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

dataset = load_breast_cancer()

# %%
sns.set_style('dark')
import matplotlib as mpl
mpl.style.use(['https://gist.githubusercontent.com/BrendanMartin/01e71bb9550774e2ccff3af7574c0020/raw/6fa9681c7d0232d34c9271de9be150e584e606fe/lds_default.mplstyle'])
mpl.rcParams.update({"figure.figsize": (8,6), "axes.titlepad": 22.0})

# %%
print('Qiymatlar  : ', dataset['target_names'])

(unique, counts) = np.unique(dataset['target'], return_counts=True)

print('Qiymat o\'zaruvchilarning yagona qiymatlari: ', unique)
print('Soni :', counts)
# Out:
# Qiymatlar  :  ['malignant' 'benign']
# Qiymat o'zaruvchilarning yagona qiymatlari:  [0 1]
# Soni : [212 357]

# %%
sns.barplot(x=dataset['target_names'], y=counts)
plt.title('Ma\'lumotlar to\'plamidagi qiymatlarimiz')
plt.show()
